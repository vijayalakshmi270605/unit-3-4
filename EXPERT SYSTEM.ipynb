# %%
import time
print("\t\tWELCOME TO AUTOMOBILE AI EXPERT SYSTEM\t\t")
print("\n\nAI:DO YOU HAVE ANY PROBLEM WITH YOUR VEHICLE?(yes or no)\n")
choice1=input("YOU:")
if choice1=="yes":
    print("\n Enter the type of issue listen doen below:\n1.starting trouble\n2.woubble while driving\n3.I don't have any issue\n")
    choice2=input("\n Enter Here (Numbers only):")
    if choice2>"3" or choice2<"1":
        print("\nAI:Please Enter valid key...")
    elif choice2=="3":
        print("\nAI:Then, Why are you enter Yes in the first question...You fool")
    elif choice2=="2":
        print("\nAI:Ok let me think...!\n")
        for i in range(1,20):
            time.sleep(0.08)
            print(".",flush=True,end="")
        print("\nAI: when do you feel the woubbling\n1.while deive on the highway at terrible speed\n2.while driving on normal road\n")
        choice3=input("YOU:")
        if choice3=="1":
            print("\nAI:Please wait still...\nAI: I wanna call police...\nAI: Just kidding....Go slow my friend")
        elif choice3=="2":
            print("\nAI:Check your tire air pressure then check inform me kindly\n")
            print("\nAI:Still you feel woubble?(yes or no)\n")
            choice4=input("YOU:")
            if choice4=="no":
                print("\nAI: I'm glad to helped you....\n Thank you....!\Call me again\n")
            elif choice4=="yes":
                print("\nAI:think,you have to make a phone call to your service\n")
            else:
                print("\nAI: will you please enter the correct answer....\n Go on run again me")
        else:
            print("\n AI : Please enter a valid key...")
    else:  
        print("\nAI: Let me remmember that you have to check that the key is inserted?\nAI:Is it inserted?(yes or no)")
        choice5=input("YOU:")
        if choice5=='no':
            print("\nAI: I think you have to study hard.... better than a ride a bike....\nAI thank you...!")
        elif choice5=='yes':
            print("\nAI: Oh i see.. let me think what to do wait a sec..\n")
            for i in range(1,30):
                time.sleep(0.08)
                print(".",flush=True,end="")
            print("\n\nAI:sorry buddy I didn't get anything in my mind... I think you have to reach service centre.")
        else:
            print("\n I'm getting bore when you enter wrong answer,'{}' it doesn't make any sense".format(choice5))
elif choice1 == 'no':
    print("\nAI: Then why are you waste my time...")
else:
    print("AI:Enter valid key")
# Out:
# 		WELCOME TO AUTOMOBILE AI EXPERT SYSTEM
#
#
# AI:DO YOU HAVE ANY PROBLEM WITH YOUR VEHICLE?(yes or no)
#
# YOU:yes
#
#  Enter the type of issue listen doen below:
# 1.starting trouble
# 2.woubble while driving
# 3.I don't have any issue
#
#
#  Enter Here (Numbers only):2
#
# AI:Ok let me think...!
#
# ...................
# AI: when do you feel the woubbling
# 1.while deive on the highway at terrible speed
# 2.while driving on normal road
#
# YOU:2
#
# AI:Check your tire air pressure then check inform me kindly
#
#
# AI:Still you feel woubble?(yes or no)
#
# YOU:yes
#
# AI:think,you have to make a phone call to your service
